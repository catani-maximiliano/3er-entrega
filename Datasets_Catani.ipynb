# %% [markdown]
# <a href="https://colab.research.google.com/github/catani-maximiliano/3er-entrega/blob/main/Datasets_Catani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Definir el nombre del archivo CSV
csv_file = '/content/drive/MyDrive/Colab Notebooks/BTCUSDT-1m-2023-08-01.csv'

# Leer el CSV y crear un DataFrame
data_velas = pd.read_csv(csv_file, header=None)

# Definir los nombres de las columnas
column_names = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
                'quote_volume', 'count', 'taker_buy_volume', 'taker_buy_quote_volume', 'ignore']

# Asignar los nombres de las columnas al DataFrame
data_velas.columns = column_names

# Mostrar el DataFrame
data_velas
# Out:
#           open_time      open      high       low     close     volume  \
# 0     1690848000000  29232.26  29232.26  29230.00  29230.00    4.86716
# 1     1690848060000  29230.01  29230.01  29228.94  29228.94    5.89128
# 2     1690848120000  29228.94  29228.95  29228.94  29228.95    4.13365
# 3     1690848180000  29228.95  29228.95  29228.94  29228.95    4.88450
# 4     1690848240000  29228.94  29228.95  29228.94  29228.94    4.44033
# ...             ...       ...       ...       ...       ...        ...
# 1435  1690934100000  29657.55  29710.80  29640.00  29640.01  445.15456
# 1436  1690934160000  29640.01  29682.30  29638.38  29664.01  216.44275
# 1437  1690934220000  29664.01  29686.00  29664.00  29684.00  117.28113
# 1438  1690934280000  29683.99  29720.00  29680.23  29682.01  187.85022
# 1439  1690934340000  29682.02  29739.25  29682.01  29705.99  178.91196
#
#          close_time  quote_volume  count  taker_buy_volume  \
# ...

# %% [markdown]
# ![Screenshot 2023-09-11 021628.png](data:image/png;base64,...)

# %% [markdown]
# Todos estos valores son todos importantes para realizar lo graficos de velas japonesas.
#
# los datos de la tabla son todos para velas de una temporalidad de un minuto.
#
# ademas tambien aporta el valor de Volumen y de numero de operaciones, que son muy importantes tambien para el analisis tecnico del grafico.

# %%
# Definir el nombre del archivo CSV
csv_file_1 = '/content/drive/MyDrive/Colab Notebooks/BTCUSDT-trades-2023-08-01.csv'

# Leer el CSV y crear un DataFrame
data_operaciones = pd.read_csv(csv_file_1, header=None)

# Definir los nombres de las columnas
column_names_trades = ['id','price','qty','base_qty','time','is_buyer_maker','is_maker']

# Asignar los nombres de las columnas al DataFrame
data_operaciones.columns = column_names_trades

# Mostrar el DataFrame
data_operaciones
# Out:
# <ipython-input-12-51460cb36e41>:5: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_operaciones = pd.read_csv(csv_file_1, header=None)
#                 id     price      qty     base_qty           time  \
# 0       3182273812  29232.26  0.00402   117.513685  1690848000000
# 1       3182273813  29232.26  0.00034     9.938968  1690848000005
# 2       3182273814  29232.26  0.00121    35.371035  1690848000005
# 3       3182273815  29232.26  0.00034     9.938968  1690848000006
# 4       3182273816  29232.26  0.00034     9.938968  1690848000006
# ...            ...       ...      ...          ...            ...
# 325291  3182599103  28920.00  0.05713  1652.199600  1690886404725
# 325292  3182599104  28920.01  0.00035    10.122003  1690886404954
# 325293  3182599105  28920.00  0.00894   258.544800  1690886405428
# 325294  3182599106  28920.01  0.00035    10.122003  1690886405474
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Los datos históricos de operaciones proporcionan una base sólida para el análisis técnico, la toma de decisiones y la evaluación del mercado en el trading. Al comprender y utilizar eficazmente estos datos, los traders pueden mejorar su capacidad para tomar decisiones informadas y gestionar su riesgo de manera efectiva en los mercados financieros.
#
# Tambien esta el campo is_buyer_maker. Estos campos se utilizan para rastrear quién inició la operación (comprador o vendedor) y si el participante en la operación fue el creador de la orden o el tomador de la orden. Estos detalles pueden ser útiles para el análisis y la comprensión de la dinámica del mercado en un intercambio de criptomonedas.

# %%
# Definir el nombre del archivo CSV
csv_file_2 = '/content/drive/MyDrive/Colab Notebooks/BTCUSDT-aggTrades-2023-08-01.csv'

# Leer el CSV y crear un DataFrame
data_aggtrades = pd.read_csv(csv_file_2, header=None)

# Definir los nombres de las columnas
column_names_aggtrades = ['agg_trade_id','price','quantity','first_trade_id','last_trade_id','transact_time','is_buyer_maker','is_maker']

# Asignar los nombres de las columnas al DataFrame
data_aggtrades.columns = column_names_aggtrades

# Mostrar el DataFrame
data_aggtrades
# Out:
#         agg_trade_id     price  quantity  first_trade_id  last_trade_id  \
# 0         2681310448  29232.26   0.00402      3182273812     3182273812
# 1         2681310449  29232.26   0.00034      3182273813     3182273813
# 2         2681310450  29232.26   0.00121      3182273814     3182273814
# 3         2681310451  29232.26   0.00034      3182273815     3182273815
# 4         2681310452  29232.26   0.00034      3182273816     3182273816
# ...              ...       ...       ...             ...            ...
# 613665    2681924113  29705.98   0.00789      3183173947     3183173947
# 613666    2681924114  29705.98   0.00307      3183173948     3183173948
# 613667    2681924115  29705.98   0.00466      3183173949     3183173949
# 613668    2681924116  29705.98   0.00068      3183173950     3183173950
# 613669    2681924117  29705.99   0.00342      3183173951     3183173952
#
#         transact_time  is_buyer_maker  is_maker
# 0       1690848000000           False      True
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esta tablas de datos se trata de las operaciones agregadas, que simplifican y resumen la información de múltiples operaciones individuales, lo que facilita su análisis y su utilidad en la toma de decisiones en el trading y la inversión.
